# %%
import torch
from models.CNNs import CNNs1D
from models.CNNRNNs import CNNRNNs
from models.CNNTransformer import CNNTransformer
from utils.pytorch_tools.model_analysis_tools import OneBranchModelTools
from utils.common_params import *

input_size = (1, C, window)
batch_size = 32

# %%
# CNNs
model = CNNs1D()
model_name = model.get_model_name()
print(model_name)
model_tools = OneBranchModelTools(model, input_size, batch_size, device)
model_tools.test_output_shape()
model_tools.summary_model(method='torchinfo') # 'torchsummary' / 'torchinfo' / 'fvcore'
# model_tools.plot_model(model_name=model_name, save_format='pdf', show=True, verbose=False)
macs, params = model_tools.calculate_complexity(verbose=True, print_log=True)
# Out:
# CNNs1D
#
# ================================================================================2025-02-16 20:31:38
# Test model output dimensions: ...
# output.shape torch.Size([32, 5])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNNs1D                                   [1, 5]                    --
# ├─Sequential: 1-1                        [1, 16, 9, 32]            --
# │    └─Conv2d: 2-1                       [1, 16, 9, 128]           96
# │    └─BatchNorm2d: 2-2                  [1, 16, 9, 128]           32
# │    └─ReLU: 2-3                         [1, 16, 9, 128]           --
# │    └─MaxPool2d: 2-4                    [1, 16, 9, 32]            --
# │    └─Dropout: 2-5                      [1, 16, 9, 32]            --
# ├─SCAttBlock: 1-2                        [1, 16, 9, 32]            --
# │    └─SRU: 2-6                          [1, 16, 9, 32]            --
# │    │    └─GroupBatchnorm2d: 3-1        [1, 16, 9, 32]            32
# │    │    └─Sigmoid: 3-2                 [1, 16, 9, 32]            --
# │    └─CRU: 2-7                          [1, 16, 9, 32]            --
# │    │    └─Conv2d: 3-3                  [1, 4, 9, 32]             32
# │    │    └─Conv2d: 3-4                  [1, 4, 9, 32]             32
# │    │    └─Conv2d: 3-5                  [1, 16, 9, 32]            112
# │    │    └─Conv2d: 3-6                  [1, 16, 9, 32]            64
# │    │    └─Conv2d: 3-7                  [1, 12, 9, 32]            48
# │    │    └─AdaptiveAvgPool2d: 3-8       [1, 32, 1, 1]             --
# ├─Sequential: 1-3                        [1, 64, 9, 1]             --
# │    └─Conv2d: 2-8                       [1, 32, 9, 32]            1,568
# │    └─BatchNorm2d: 2-9                  [1, 32, 9, 32]            64
# │    └─ReLU: 2-10                        [1, 32, 9, 32]            --
# │    └─MaxPool2d: 2-11                   [1, 32, 9, 8]             --
# │    └─Dropout: 2-12                     [1, 32, 9, 8]             --
# │    └─Conv2d: 2-13                      [1, 64, 9, 8]             6,208
# │    └─BatchNorm2d: 2-14                 [1, 64, 9, 8]             128
# │    └─ReLU: 2-15                        [1, 64, 9, 8]             --
# │    └─AvgPool2d: 2-16                   [1, 64, 9, 1]             --
# │    └─Dropout: 2-17                     [1, 64, 9, 1]             --
# ├─Sequential: 1-4                        [1, 256, 1, 1]            --
# │    └─Conv2d: 2-18                      [1, 128, 9, 1]            24,704
# │    └─BatchNorm2d: 2-19                 [1, 128, 9, 1]            256
# │    └─ReLU: 2-20                        [1, 128, 9, 1]            --
# │    └─MaxPool2d: 2-21                   [1, 128, 3, 1]            --
# │    └─Dropout: 2-22                     [1, 128, 3, 1]            --
# │    └─Conv2d: 2-23                      [1, 256, 3, 1]            98,560
# │    └─BatchNorm2d: 2-24                 [1, 256, 3, 1]            512
# │    └─ReLU: 2-25                        [1, 256, 3, 1]            --
# │    └─AvgPool2d: 2-26                   [1, 256, 1, 1]            --
# │    └─Dropout: 2-27                     [1, 256, 1, 1]            --
# ├─Sequential: 1-5                        [1, 5]                    --
# │    └─Linear: 2-28                      [1, 32]                   8,224
# │    └─BatchNorm1d: 2-29                 [1, 32]                   64
# │    └─ReLU: 2-30                        [1, 32]                   --
# │    └─Dropout: 2-31                     [1, 32]                   --
# │    └─Linear: 2-32                      [1, 5]                    165
# ==========================================================================================
# Total params: 140,901
# Trainable params: 140,901
# Non-trainable params: 0
# Total mult-adds (M): 1.619589
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.70
# Params size (MB): 0.56
# Estimated Total Size (MB): 1.27
# ==========================================================================================
#
# ================================================================================2025-02-16 20:31:42
# Calculate model complexity: ...
#
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [WARN] Cannot find rule for <class 'models.SCAttention.GroupBatchnorm2d'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.activation.Sigmoid'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'models.SCAttention.SRU'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [WARN] Cannot find rule for <class 'models.SCAttention.CRU'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'models.SCAttention.SCAttBlock'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_avgpool() for <class 'torch.nn.modules.pooling.AvgPool2d'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm1d'>.
# [WARN] Cannot find rule for <class 'models.CNNs.CNNs1D'>. Treat it as zero Macs and zero Params.
# macs: 55250944.0 params: 140869.0

# %%
# CNNRNNs
rnn_type = 'LSTM' # ['LSTM', 'GRU', 'BiLSTM', 'BiGRU']
model = CNNRNNs(rnn_type=rnn_type)
model_name = model.get_model_name()
print(model_name)
model_tools = OneBranchModelTools(model, input_size, batch_size, device)
model_tools.test_output_shape()
model_tools.summary_model(method='torchinfo') # 'torchsummary' / 'torchinfo' / 'fvcore'
# model_tools.plot_model(model_name=model_name, save_format='pdf', show=True, verbose=False)
macs, params = model_tools.calculate_complexity(verbose=True, print_log=True)
# Out:
# CNN-LSTM
#
# ================================================================================2025-02-16 20:32:41
# Test model output dimensions: ...
# output.shape torch.Size([32, 5])
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNNRNNs                                  [1, 5]                    --
# ├─Sequential: 1-1                        [1, 16, 9, 32]            --
# │    └─Conv2d: 2-1                       [1, 16, 9, 128]           96
# │    └─BatchNorm2d: 2-2                  [1, 16, 9, 128]           32
# │    └─ReLU: 2-3                         [1, 16, 9, 128]           --
# │    └─MaxPool2d: 2-4                    [1, 16, 9, 32]            --
# │    └─Dropout: 2-5                      [1, 16, 9, 32]            --
# ├─SCAttBlock: 1-2                        [1, 16, 9, 32]            --
# │    └─SRU: 2-6                          [1, 16, 9, 32]            --
# │    │    └─GroupBatchnorm2d: 3-1        [1, 16, 9, 32]            32
# │    │    └─Sigmoid: 3-2                 [1, 16, 9, 32]            --
# │    └─CRU: 2-7                          [1, 16, 9, 32]            --
# │    │    └─Conv2d: 3-3                  [1, 4, 9, 32]             32
# │    │    └─Conv2d: 3-4                  [1, 4, 9, 32]             32
# │    │    └─Conv2d: 3-5                  [1, 16, 9, 32]            112
# │    │    └─Conv2d: 3-6                  [1, 16, 9, 32]            64
# │    │    └─Conv2d: 3-7                  [1, 12, 9, 32]            48
# │    │    └─AdaptiveAvgPool2d: 3-8       [1, 32, 1, 1]             --
# ├─Sequential: 1-3                        [1, 32, 9, 8]             --
# │    └─Conv2d: 2-8                       [1, 32, 9, 32]            1,568
# │    └─BatchNorm2d: 2-9                  [1, 32, 9, 32]            64
# │    └─ReLU: 2-10                        [1, 32, 9, 32]            --
# │    └─MaxPool2d: 2-11                   [1, 32, 9, 8]             --
# │    └─Dropout: 2-12                     [1, 32, 9, 8]             --
# ├─LSTM: 1-4                              [1, 8, 64]                90,624
# ├─LSTM: 1-5                              [1, 8, 128]               99,328
# ├─Sequential: 1-6                        [1, 5]                    --
# │    └─Linear: 2-13                      [1, 32]                   4,128
# │    └─BatchNorm1d: 2-14                 [1, 32]                   64
# │    └─ReLU: 2-15                        [1, 32]                   --
# │    └─Dropout: 2-16                     [1, 32]                   --
# │    └─Linear: 2-17                      [1, 5]                    165
# ==========================================================================================
# Total params: 196,389
# Trainable params: 196,389
# Non-trainable params: 0
# Total mult-adds (M): 2.169221
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.61
# Params size (MB): 0.79
# Estimated Total Size (MB): 1.40
# ==========================================================================================
#
# ================================================================================2025-02-16 20:32:41
# Calculate model complexity: ...
#
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [WARN] Cannot find rule for <class 'models.SCAttention.GroupBatchnorm2d'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.activation.Sigmoid'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'models.SCAttention.SRU'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [WARN] Cannot find rule for <class 'models.SCAttention.CRU'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'models.SCAttention.SCAttBlock'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_lstm() for <class 'torch.nn.modules.rnn.LSTM'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm1d'>.
# [WARN] Cannot find rule for <class 'models.CNNRNNs.CNNRNNs'>. Treat it as zero Macs and zero Params.
# macs: 72607744.0 params: 196357.0

# %%
# CNNTransformer
model = CNNTransformer()
model_name = model.get_model_name()
print(model_name)
model_tools = OneBranchModelTools(model, input_size, batch_size, device)
model_tools.test_output_shape()
model_tools.summary_model(method='torchinfo') # 'torchsummary' / 'torchinfo' / 'fvcore'
# model_tools.plot_model(model_name=model_name, save_format='pdf', show=True, verbose=False)
macs, params = model_tools.calculate_complexity(verbose=True, print_log=True)
# Out:
# CNNTransformer
#
# ================================================================================2025-02-16 20:33:34
# Test model output dimensions: ...
#
# output.shape torch.Size([32, 5])
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# CNNTransformer                                [1, 5]                    --
# ├─Sequential: 1-1                             [1, 16, 9, 32]            --
# │    └─Conv2d: 2-1                            [1, 16, 9, 128]           96
# │    └─BatchNorm2d: 2-2                       [1, 16, 9, 128]           32
# │    └─ReLU: 2-3                              [1, 16, 9, 128]           --
# │    └─MaxPool2d: 2-4                         [1, 16, 9, 32]            --
# │    └─Dropout: 2-5                           [1, 16, 9, 32]            --
# ├─SCAttBlock: 1-2                             [1, 16, 9, 32]            --
# │    └─SRU: 2-6                               [1, 16, 9, 32]            --
# │    │    └─GroupBatchnorm2d: 3-1             [1, 16, 9, 32]            32
# │    │    └─Sigmoid: 3-2                      [1, 16, 9, 32]            --
# │    └─CRU: 2-7                               [1, 16, 9, 32]            --
# │    │    └─Conv2d: 3-3                       [1, 4, 9, 32]             32
# │    │    └─Conv2d: 3-4                       [1, 4, 9, 32]             32
# │    │    └─Conv2d: 3-5                       [1, 16, 9, 32]            112
# │    │    └─Conv2d: 3-6                       [1, 16, 9, 32]            64
# │    │    └─Conv2d: 3-7                       [1, 12, 9, 32]            48
# │    │    └─AdaptiveAvgPool2d: 3-8            [1, 32, 1, 1]             --
# ├─Sequential: 1-3                             [1, 64, 9, 1]             --
# │    └─Conv2d: 2-8                            [1, 32, 9, 32]            1,568
# │    └─BatchNorm2d: 2-9                       [1, 32, 9, 32]            64
# │    └─ReLU: 2-10                             [1, 32, 9, 32]            --
# │    └─MaxPool2d: 2-11                        [1, 32, 9, 8]             --
# │    └─Dropout: 2-12                          [1, 32, 9, 8]             --
# │    └─Conv2d: 2-13                           [1, 64, 9, 8]             6,208
# │    └─BatchNorm2d: 2-14                      [1, 64, 9, 8]             128
# │    └─ReLU: 2-15                             [1, 64, 9, 8]             --
# │    └─MaxPool2d: 2-16                        [1, 64, 9, 1]             --
# │    └─Dropout: 2-17                          [1, 64, 9, 1]             --
# ├─Sequential: 1-4                             [1, 256, 1, 1]            --
# │    └─Conv2d: 2-18                           [1, 128, 9, 1]            24,704
# │    └─BatchNorm2d: 2-19                      [1, 128, 9, 1]            256
# │    └─ReLU: 2-20                             [1, 128, 9, 1]            --
# │    └─MaxPool2d: 2-21                        [1, 128, 3, 1]            --
# │    └─Dropout: 2-22                          [1, 128, 3, 1]            --
# │    └─Conv2d: 2-23                           [1, 256, 3, 1]            98,560
# │    └─BatchNorm2d: 2-24                      [1, 256, 3, 1]            512
# │    └─ReLU: 2-25                             [1, 256, 3, 1]            --
# │    └─AvgPool2d: 2-26                        [1, 256, 1, 1]            --
# │    └─Dropout: 2-27                          [1, 256, 1, 1]            --
# ├─TransformerEncoder: 1-5                     [1, 32, 144]              --
# │    └─ModuleList: 2-28                       --                        --
# │    │    └─TransformerEncoderLayer: 3-9      [1, 32, 144]              158,224
# │    │    └─TransformerEncoderLayer: 3-10     [1, 32, 144]              158,224
# │    │    └─TransformerEncoderLayer: 3-11     [1, 32, 144]              158,224
# │    │    └─TransformerEncoderLayer: 3-12     [1, 32, 144]              158,224
# ├─Sequential: 1-6                             [1, 5]                    --
# │    └─Linear: 2-29                           [1, 32]                   9,248
# │    └─BatchNorm1d: 2-30                      [1, 32]                   64
# │    └─ReLU: 2-31                             [1, 32]                   --
# │    └─Dropout: 2-32                          [1, 32]                   --
# │    └─Linear: 2-33                           [1, 5]                    165
# ===============================================================================================
# Total params: 774,821
# Trainable params: 774,821
# Non-trainable params: 0
# Total mult-adds (M): 1.620613
# ===============================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.70
# Params size (MB): 0.57
# Estimated Total Size (MB): 1.28
# ===============================================================================================
#
# ================================================================================2025-02-16 20:33:34
# Calculate model complexity: ...
#
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv2d'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool2d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.dropout.Dropout'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [WARN] Cannot find rule for <class 'models.SCAttention.GroupBatchnorm2d'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.activation.Sigmoid'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'models.SCAttention.SRU'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_adap_avgpool() for <class 'torch.nn.modules.pooling.AdaptiveAvgPool2d'>.
# [WARN] Cannot find rule for <class 'models.SCAttention.CRU'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'models.SCAttention.SCAttBlock'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_avgpool() for <class 'torch.nn.modules.pooling.AvgPool2d'>.
# [WARN] Cannot find rule for <class 'torch.nn.modules.linear.NonDynamicallyQuantizableLinear'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.activation.MultiheadAttention'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.normalization.LayerNorm'>.
# [WARN] Cannot find rule for <class 'torch.nn.modules.transformer.TransformerEncoderLayer'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.container.ModuleList'>. Treat it as zero Macs and zero Params.
# [WARN] Cannot find rule for <class 'torch.nn.modules.transformer.TransformerEncoder'>. Treat it as zero Macs and zero Params.
# [INFO] Register count_normalization() for <class 'torch.nn.modules.batchnorm.BatchNorm1d'>.
# [WARN] Cannot find rule for <class 'models.CNNTransformer.CNNTransformer'>. Treat it as zero Macs and zero Params.
# macs: 55265280.0 params: 141893.0
