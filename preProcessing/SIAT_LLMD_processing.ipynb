# %%
import os
# When using on Juypter Notebook, uncomment the code below
# import sys
# path = os.path.join(os.path.dirname(os.getcwd()))
# sys.path.append(path) 
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from utils.common_utils import printlog, make_dir
from utils.processing_tools.processing import *
from utils.feature_extraction_tools.feature_extraction import emg_feature_extraction
from utils.common_params import *

# %%
### Parameter Settings
## 1. Original file path
raw_file_path = 'SIAT_LLMD_rawData'

## 2. Subject and Exercise type Settings
subjects_list_global = list(['01','02','03','04','05', '31','32','33','34','35'])
motions_list_global = ['WAK', 'STDUP', 'SITDN', 'UPS', 'DNS'] 

## 3. Channel (column) name of emg in the raw data used
emg_name = ['sEMG: tensor fascia lata', 'sEMG: rectus femoris', 'sEMG: vastus medialis',
            'sEMG: semimembranosus', 'sEMG: upper tibialis anterior', 'sEMG: lower tibialis anterior',
            'sEMG: lateral gastrocnemius', 'sEMG: medial gastrocnemius', 'sEMG: soleus']

## 4. Data Preprocessing Settings
# 4.1. Downsampling: 1920 Hz - 1000 Hz
# 4.2. emg notch filter (3rd order FIR notch filter, 50Hz, band width 2Hz)
# 4.3. emg Butterworth filter (low cut-off frequency :15hz; High cut-off frequency :450hz; Order :7)
# 4.4. emg denoising
## 4.4.1 ICEEMDAN-PE-GT/SVD
## 4.4.1.1 ICEEMDAN: Noise amplitude, ε0 = 0.2; Number of the noise realizations, I=100;
## 4.4.1.2 Adaptive PE decision threshold
## 4.4.1.3GT: Threshold: improvement of the 'universal' threshold (visushrink); Threshold rule: garrote threshold
## 4.4.2 WD-GT(Wavelet denoising, wavelet basis' db5 ', decomposition level 3, Threshold rule: garrote threshold, Threshold universal threshold 'universal')
## 4.4.3 WPD-GT(wavelet packet denoising, wavelet basis' db5 ', decomposition level 3, Threshold rule: garrote threshold, threshold universal threshold 'universal')
# 4.5. emg normalization
emg_denoise_method = 'rawdata'  # ['rawdata', 'WD-GT', 'WPD-GT', 'EMD-PE-GT', 'EMD-PE-SVD', 'ICEEMDAN-PE-GT', 'ICEEMDAN-PE-SVD']
data_normalize_method = 'positive_negative_one' # 'min-max' (0, 1), 'max-abs' (-1,1), 'positive_negative_one' (-1, 1)
data_normalize_level = 'matrix' # 'matrix' / 'rows' 

## 5. Overlapping window sampling: overlapping window length, step length

## 6. Feature extraction settings for emg and joint angle data
emg_channels = ['TFL', 'RF', 'VM', 'SEM', 'UTA', 'LTA', 'LG', 'MG', 'SOL']
emg_feature_type = ['MAV', 'RMS', 'WL', 'ZC', 'SSC', 'WAMP']
fea_normalize_method = 'min-max'
fea_normalize_level = 'rows'

# %%
for i in range(len(subjects_list_global)):
    subject = 'Sub' + subjects_list_global[i]
    data_file_dir = os.path.join(raw_file_path,subject,'Data')
    label_file_dir = os.path.join(raw_file_path,subject,'Labels')
    sub_emg_sample, sub_emg_features, sub_motion_label_raw = [], [], []
    printlog(info = ''.join(['Start processing:  ', subject]), time = True, line_break = False)
    
    for j in range(len(motions_list_global)):
        motion = motions_list_global[j]
        printlog(info = "\n"+"********"*4 +''.join([' motion: ', motion, ' '])+"********"*4, time = False, line_break = False)
        printlog (info = 'step1: Load data and label...', time = False, line_break = False)
        ## 1.1 data and label filenames
        data_file_name = os.path.join(data_file_dir,''.join([subject, '_', motion, '_Data.csv']))
        label_file_name = os.path.join(label_file_dir,''.join([subject, '_', motion, '_Label.csv']))
        ## 1.2 read data and label
        df_data = pd.read_csv(data_file_name,header=0)
        time = df_data.loc[:, ['Time']].values
        emg_raw_data = df_data.loc[:, emg_name].values
        df_label = pd.read_csv(label_file_name,header=0)
        status_label = df_label.loc[:, ['Status']].values
        group_label = df_label.loc[:, ['Group']].values
        
        printlog ('step2: Data preprocessing...', time = False, line_break = False)
        ## 2.0 Determine whether an active segment signal is needed
        emg_act_data = get_emg_act_signal(motion, emg_raw_data, status_label)
        ## 2.1 Resampling
        emg_resample_data = signal2d_resampling(emg_act_data, raw_fs, tar_fs)
        ## 2.2 Filtering
        emg_filtered_data = emg_filtering(emg_resample_data, tar_fs)
        ## 2.3 Denosing
        emg_denoise_data = Signal2dDenoise(data=emg_filtered_data, denoise_method=emg_denoise_method).forward()
        ## 2.4 Normalization
        emg_data_pre = data_nomalize(emg_denoise_data, data_normalize_method, data_normalize_level)
        printlog ('step3: Overlapping window segmentation...', time = False, line_break = False)
        emg_sample, motion_label_raw = movement_classification_sample_segmentation(motion, emg_data_pre, window, step)
        printlog ('step4: Feature extraction...', time = False, line_break = False)
        emg_features, emg_feature_list = emg_feature_extraction(emg_sample, emg_channels, emg_feature_type, fea_normalize_method, fea_normalize_level)
        printlog ('step5: Merging: all emg data, features, labels...', time = False, line_break = False)
        sub_emg_sample.extend(emg_sample)
        sub_emg_features.extend(emg_features)
        sub_motion_label_raw.extend(motion_label_raw)
        
    printlog(info = ''.join(['Merging: ', subject, 'data for all motion types...']), time = True, line_break = False)
    sub_emg_sample = np.swapaxes(np.array(sub_emg_sample), 1, 2)   # Swap the second and third dimensions to become: num*len(emg_channels)*len(window)
    sub_emg_features, sub_motion_label_raw = np.array(sub_emg_features), np.array(sub_motion_label_raw)
    printlog(info = ''.join(['Subject: ', subject, 'numeric labels and one-hot labels for all motion types...']), time = False, line_break = False)
    label_encoder = LabelEncoder()
    sub_motion_label_encoded_raw = label_encoder.fit_transform(sub_motion_label_raw) 
    custom_order = motions_list_global
    label_encoder.classes_ = custom_order
    sub_motion_label_encoded = np.array([custom_order.index(label) for label in sub_motion_label_raw])
    onehot_encoder = OneHotEncoder(sparse_output=False) 
    sub_motion_label_onehot = onehot_encoder.fit_transform(sub_motion_label_encoded.reshape(-1, 1))
    printlog(info = ''.join(['Subject: ', subject, ', ', 'done!']), time = False, line_break = False)
    print('emg_sample.shape: ', sub_emg_sample.shape)
    print('emg_features.shape: ', sub_emg_features.shape)
    print('motion_label_raw.shape: ', sub_motion_label_raw.shape, ', motion_label_encoded.shape: ', sub_motion_label_encoded.shape, ', motion_label_onehot.shape: ', sub_motion_label_onehot.shape)
    
    file_save_path = os.path.join(os.getcwd(), 'SIAT_LLMD_trainData', emg_denoise_method)
    make_dir(file_save_path)
    file_save_name = os.path.join(file_save_path,''.join([subject,'_targetTrainData.npz']))
    with open(file_save_name, 'wb') as f:
        np.savez(f, sub_emg_sample = sub_emg_sample, sub_emg_features = sub_emg_features, sub_motion_label_raw = sub_motion_label_raw,
        sub_motion_label_encoded = sub_motion_label_encoded, sub_motion_label_onehot = sub_motion_label_onehot)
    printlog(info = file_save_name, time = False, line_break = False)
# Out:
# ================================================================================2025-02-16 23:04:43
# Start processing:  Sub01
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 14148
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (146, 128, 9) , movement_label.shape:  (146,)
# step4: Feature extraction...
#        emg_feas.shape:  (146, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 8760
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (89, 128, 9) , movement_label.shape:  (89,)
# step4: Feature extraction...
#        emg_feas.shape:  (89, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 9714
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (99, 128, 9) , movement_label.shape:  (99,)
# step4: Feature extraction...
#        emg_feas.shape:  (99, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 18479
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (191, 128, 9) , movement_label.shape:  (191,)
# step4: Feature extraction...
#        emg_feas.shape:  (191, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 15973
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (165, 128, 9) , movement_label.shape:  (165,)
# step4: Feature extraction...
#        emg_feas.shape:  (165, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:04:51
# Merging: Sub01data for all motion types...
# Subject: Sub01numeric labels and one-hot labels for all motion types...
# Subject: Sub01, done!
# emg_sample.shape:  (690, 9, 128)
# emg_features.shape:  (690, 9, 6)
# motion_label_raw.shape:  (690,) , motion_label_encoded.shape:  (690,) , motion_label_onehot.shape:  (690, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub01_targetTrainData.npz
#
# ================================================================================2025-02-16 23:04:51
# Start processing:  Sub02
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 10792
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (111, 128, 9) , movement_label.shape:  (111,)
# step4: Feature extraction...
#        emg_feas.shape:  (111, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 6036
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (61, 128, 9) , movement_label.shape:  (61,)
# step4: Feature extraction...
#        emg_feas.shape:  (61, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 6552
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (66, 128, 9) , movement_label.shape:  (66,)
# step4: Feature extraction...
#        emg_feas.shape:  (66, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 13200
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (136, 128, 9) , movement_label.shape:  (136,)
# step4: Feature extraction...
#        emg_feas.shape:  (136, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 10628
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (109, 128, 9) , movement_label.shape:  (109,)
# step4: Feature extraction...
#        emg_feas.shape:  (109, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:04:53
# Merging: Sub02data for all motion types...
# Subject: Sub02numeric labels and one-hot labels for all motion types...
# Subject: Sub02, done!
# emg_sample.shape:  (483, 9, 128)
# emg_features.shape:  (483, 9, 6)
# motion_label_raw.shape:  (483,) , motion_label_encoded.shape:  (483,) , motion_label_onehot.shape:  (483, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub02_targetTrainData.npz
#
# ================================================================================2025-02-16 23:04:53
# Start processing:  Sub03
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 10831
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (111, 128, 9) , movement_label.shape:  (111,)
# step4: Feature extraction...
#        emg_feas.shape:  (111, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 6619
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (67, 128, 9) , movement_label.shape:  (67,)
# step4: Feature extraction...
#        emg_feas.shape:  (67, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 7826
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (80, 128, 9) , movement_label.shape:  (80,)
# step4: Feature extraction...
#        emg_feas.shape:  (80, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 10514
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (108, 128, 9) , movement_label.shape:  (108,)
# step4: Feature extraction...
#        emg_feas.shape:  (108, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 15241
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (157, 128, 9) , movement_label.shape:  (157,)
# step4: Feature extraction...
#        emg_feas.shape:  (157, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:04:56
# Merging: Sub03data for all motion types...
# Subject: Sub03numeric labels and one-hot labels for all motion types...
# Subject: Sub03, done!
# emg_sample.shape:  (523, 9, 128)
# emg_features.shape:  (523, 9, 6)
# motion_label_raw.shape:  (523,) , motion_label_encoded.shape:  (523,) , motion_label_onehot.shape:  (523, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub03_targetTrainData.npz
#
# ================================================================================2025-02-16 23:04:56
# Start processing:  Sub04
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 11803
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (121, 128, 9) , movement_label.shape:  (121,)
# step4: Feature extraction...
#        emg_feas.shape:  (121, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 6929
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (70, 128, 9) , movement_label.shape:  (70,)
# step4: Feature extraction...
#        emg_feas.shape:  (70, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 9102
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (93, 128, 9) , movement_label.shape:  (93,)
# step4: Feature extraction...
#        emg_feas.shape:  (93, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 14245
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (147, 128, 9) , movement_label.shape:  (147,)
# step4: Feature extraction...
#        emg_feas.shape:  (147, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 11222
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (115, 128, 9) , movement_label.shape:  (115,)
# step4: Feature extraction...
#        emg_feas.shape:  (115, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:04:58
# Merging: Sub04data for all motion types...
# Subject: Sub04numeric labels and one-hot labels for all motion types...
# Subject: Sub04, done!
# emg_sample.shape:  (546, 9, 128)
# emg_features.shape:  (546, 9, 6)
# motion_label_raw.shape:  (546,) , motion_label_encoded.shape:  (546,) , motion_label_onehot.shape:  (546, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub04_targetTrainData.npz
#
# ================================================================================2025-02-16 23:04:58
# Start processing:  Sub05
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 12630
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (130, 128, 9) , movement_label.shape:  (130,)
# step4: Feature extraction...
#        emg_feas.shape:  (130, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 7047
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (72, 128, 9) , movement_label.shape:  (72,)
# step4: Feature extraction...
#        emg_feas.shape:  (72, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 7841
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (80, 128, 9) , movement_label.shape:  (80,)
# step4: Feature extraction...
#        emg_feas.shape:  (80, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 21458
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (222, 128, 9) , movement_label.shape:  (222,)
# step4: Feature extraction...
#        emg_feas.shape:  (222, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 20573
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (212, 128, 9) , movement_label.shape:  (212,)
# step4: Feature extraction...
#        emg_feas.shape:  (212, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:05:01
# Merging: Sub05data for all motion types...
# Subject: Sub05numeric labels and one-hot labels for all motion types...
# Subject: Sub05, done!
# emg_sample.shape:  (716, 9, 128)
# emg_features.shape:  (716, 9, 6)
# motion_label_raw.shape:  (716,) , motion_label_encoded.shape:  (716,) , motion_label_onehot.shape:  (716, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub05_targetTrainData.npz
#
# ================================================================================2025-02-16 23:05:01
# Start processing:  Sub31
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 12421
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (128, 128, 9) , movement_label.shape:  (128,)
# step4: Feature extraction...
#        emg_feas.shape:  (128, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 6420
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (65, 128, 9) , movement_label.shape:  (65,)
# step4: Feature extraction...
#        emg_feas.shape:  (65, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 6059
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (61, 128, 9) , movement_label.shape:  (61,)
# step4: Feature extraction...
#        emg_feas.shape:  (61, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 22139
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (229, 128, 9) , movement_label.shape:  (229,)
# step4: Feature extraction...
#        emg_feas.shape:  (229, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 13134
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (135, 128, 9) , movement_label.shape:  (135,)
# step4: Feature extraction...
#        emg_feas.shape:  (135, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:05:04
# Merging: Sub31data for all motion types...
# Subject: Sub31numeric labels and one-hot labels for all motion types...
# Subject: Sub31, done!
# emg_sample.shape:  (618, 9, 128)
# emg_features.shape:  (618, 9, 6)
# motion_label_raw.shape:  (618,) , motion_label_encoded.shape:  (618,) , motion_label_onehot.shape:  (618, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub31_targetTrainData.npz
#
# ================================================================================2025-02-16 23:05:04
# Start processing:  Sub32
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 11105
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (114, 128, 9) , movement_label.shape:  (114,)
# step4: Feature extraction...
#        emg_feas.shape:  (114, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 7000
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (71, 128, 9) , movement_label.shape:  (71,)
# step4: Feature extraction...
#        emg_feas.shape:  (71, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 7599
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (77, 128, 9) , movement_label.shape:  (77,)
# step4: Feature extraction...
#        emg_feas.shape:  (77, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 15802
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (163, 128, 9) , movement_label.shape:  (163,)
# step4: Feature extraction...
#        emg_feas.shape:  (163, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 14871
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (153, 128, 9) , movement_label.shape:  (153,)
# step4: Feature extraction...
#        emg_feas.shape:  (153, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:05:07
# Merging: Sub32data for all motion types...
# Subject: Sub32numeric labels and one-hot labels for all motion types...
# Subject: Sub32, done!
# emg_sample.shape:  (578, 9, 128)
# emg_features.shape:  (578, 9, 6)
# motion_label_raw.shape:  (578,) , motion_label_encoded.shape:  (578,) , motion_label_onehot.shape:  (578, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub32_targetTrainData.npz
#
# ================================================================================2025-02-16 23:05:07
# Start processing:  Sub33
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 11553
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (119, 128, 9) , movement_label.shape:  (119,)
# step4: Feature extraction...
#        emg_feas.shape:  (119, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 7377
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (75, 128, 9) , movement_label.shape:  (75,)
# step4: Feature extraction...
#        emg_feas.shape:  (75, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 20447
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (211, 128, 9) , movement_label.shape:  (211,)
# step4: Feature extraction...
#        emg_feas.shape:  (211, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 16708
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (172, 128, 9) , movement_label.shape:  (172,)
# step4: Feature extraction...
#        emg_feas.shape:  (172, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 13067
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (134, 128, 9) , movement_label.shape:  (134,)
# step4: Feature extraction...
#        emg_feas.shape:  (134, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:05:10
# Merging: Sub33data for all motion types...
# Subject: Sub33numeric labels and one-hot labels for all motion types...
# Subject: Sub33, done!
# emg_sample.shape:  (711, 9, 128)
# emg_features.shape:  (711, 9, 6)
# motion_label_raw.shape:  (711,) , motion_label_encoded.shape:  (711,) , motion_label_onehot.shape:  (711, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub33_targetTrainData.npz
#
# ================================================================================2025-02-16 23:05:10
# Start processing:  Sub34
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 10756
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (110, 128, 9) , movement_label.shape:  (110,)
# step4: Feature extraction...
#        emg_feas.shape:  (110, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 5380
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (54, 128, 9) , movement_label.shape:  (54,)
# step4: Feature extraction...
#        emg_feas.shape:  (54, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 5730
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (58, 128, 9) , movement_label.shape:  (58,)
# step4: Feature extraction...
#        emg_feas.shape:  (58, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 14358
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (148, 128, 9) , movement_label.shape:  (148,)
# step4: Feature extraction...
#        emg_feas.shape:  (148, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 12454
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (128, 128, 9) , movement_label.shape:  (128,)
# step4: Feature extraction...
#        emg_feas.shape:  (128, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:05:12
# Merging: Sub34data for all motion types...
# Subject: Sub34numeric labels and one-hot labels for all motion types...
# Subject: Sub34, done!
# emg_sample.shape:  (498, 9, 128)
# emg_features.shape:  (498, 9, 6)
# motion_label_raw.shape:  (498,) , motion_label_encoded.shape:  (498,) , motion_label_onehot.shape:  (498, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub34_targetTrainData.npz
#
# ================================================================================2025-02-16 23:05:12
# Start processing:  Sub35
#
# ******************************** motion: WAK ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 13651
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (140, 128, 9) , movement_label.shape:  (140,)
# step4: Feature extraction...
#        emg_feas.shape:  (140, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: STDUP ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 5414
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (55, 128, 9) , movement_label.shape:  (55,)
# step4: Feature extraction...
#        emg_feas.shape:  (55, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: SITDN ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 5366
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (54, 128, 9) , movement_label.shape:  (54,)
# step4: Feature extraction...
#        emg_feas.shape:  (54, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: UPS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 20237
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (209, 128, 9) , movement_label.shape:  (209,)
# step4: Feature extraction...
#        emg_feas.shape:  (209, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ******************************** motion: DNS ********************************
# step1: Load data and label...
# step2: Data preprocessing...
# emg denoising method: rawdata
# Signal Length: 25187
# step3: Overlapping window segmentation...
#        Overlapping window segmentation...
#        emg_sample.shape:  (261, 128, 9) , movement_label.shape:  (261,)
# step4: Feature extraction...
#        emg_feas.shape:  (261, 9, 6)
# step5: Merging: all emg data, features, labels...
#
# ================================================================================2025-02-16 23:05:16
# Merging: Sub35data for all motion types...
# Subject: Sub35numeric labels and one-hot labels for all motion types...
# Subject: Sub35, done!
# emg_sample.shape:  (719, 9, 128)
# emg_features.shape:  (719, 9, 6)
# motion_label_raw.shape:  (719,) , motion_label_encoded.shape:  (719,) , motion_label_onehot.shape:  (719, 5)
# E:\pythonCode\Code V1.0 of sEMG_LMR_Method\preProcessing\SIAT_LLMD_trainData\rawdata\Sub35_targetTrainData.npz

# %%
## Read the file, for check
file_path = os.path.join(os.getcwd(), 'SIAT_LLMD_trainData', emg_denoise_method)

for i in range(len(subjects_list_global)):
    subject = 'Sub'+subjects_list_global[i]
    printlog(info = ''.join(['Read file of: ', subject]), time = True, line_break = False)
    file_name = os.path.join(file_path,''.join([subject,'_targetTrainData.npz']))
    with open(file_name, 'rb') as f:
        sub_emg_sample = np.load(f)['sub_emg_sample']
        sub_emg_features = np.load(f)['sub_emg_features']
        sub_motion_label_raw = np.load(f)['sub_motion_label_raw']
        sub_motion_label_encoded = np.load(f)['sub_motion_label_encoded']
        sub_motion_label_onehot = np.load(f)['sub_motion_label_onehot']
    print('emg_sample.shape: ', sub_emg_sample.shape)
    print('emg_features.shape: ', sub_emg_features.shape)
    print('motion_label_raw.shape: ', sub_motion_label_raw.shape, ', movement_label_encoded.shape: ', sub_motion_label_encoded.shape, ', motion_label_onehot.shape: ', sub_motion_label_onehot.shape)
# Out:
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub01
# emg_sample.shape:  (690, 9, 128)
# emg_features.shape:  (690, 9, 6)
# motion_label_raw.shape:  (690,) , movement_label_encoded.shape:  (690,) , motion_label_onehot.shape:  (690, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub02
# emg_sample.shape:  (483, 9, 128)
# emg_features.shape:  (483, 9, 6)
# motion_label_raw.shape:  (483,) , movement_label_encoded.shape:  (483,) , motion_label_onehot.shape:  (483, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub03
# emg_sample.shape:  (523, 9, 128)
# emg_features.shape:  (523, 9, 6)
# motion_label_raw.shape:  (523,) , movement_label_encoded.shape:  (523,) , motion_label_onehot.shape:  (523, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub04
# emg_sample.shape:  (546, 9, 128)
# emg_features.shape:  (546, 9, 6)
# motion_label_raw.shape:  (546,) , movement_label_encoded.shape:  (546,) , motion_label_onehot.shape:  (546, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub05
# emg_sample.shape:  (716, 9, 128)
# emg_features.shape:  (716, 9, 6)
# motion_label_raw.shape:  (716,) , movement_label_encoded.shape:  (716,) , motion_label_onehot.shape:  (716, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub31
# emg_sample.shape:  (618, 9, 128)
# emg_features.shape:  (618, 9, 6)
# motion_label_raw.shape:  (618,) , movement_label_encoded.shape:  (618,) , motion_label_onehot.shape:  (618, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub32
# emg_sample.shape:  (578, 9, 128)
# emg_features.shape:  (578, 9, 6)
# motion_label_raw.shape:  (578,) , movement_label_encoded.shape:  (578,) , motion_label_onehot.shape:  (578, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub33
# emg_sample.shape:  (711, 9, 128)
# emg_features.shape:  (711, 9, 6)
# motion_label_raw.shape:  (711,) , movement_label_encoded.shape:  (711,) , motion_label_onehot.shape:  (711, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub34
# emg_sample.shape:  (498, 9, 128)
# emg_features.shape:  (498, 9, 6)
# motion_label_raw.shape:  (498,) , movement_label_encoded.shape:  (498,) , motion_label_onehot.shape:  (498, 5)
#
# ================================================================================2025-02-16 23:05:43
# Read file of: Sub35
# emg_sample.shape:  (719, 9, 128)
# emg_features.shape:  (719, 9, 6)
# motion_label_raw.shape:  (719,) , movement_label_encoded.shape:  (719,) , motion_label_onehot.shape:  (719, 5)
